# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e0524d29-c2f6-4e58-8a34-5c551992bd50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0524d29-c2f6-4e58-8a34-5c551992bd50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_Energy = pd.read_excel('Energy Indicators.xls')

# %%
display(df_Energy)
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# ..          ...                                                ...
# 277         NaN                       … denotes no data available.
# 278         NaN                                                NaN
# 279         NaN                                     Data Quality:
# 280         NaN  The data are compiled primarily from the annua...
# 281         NaN  For more information, visit http://unstats.un....
#
#                                             Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                     Environmental Indicators: Energy        NaN        NaN
# ...

# %%
df_Energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  260 non-null    object
#  2   Unnamed: 2  252 non-null    object
#  3   Unnamed: 3  232 non-null    object
#  4   Unnamed: 4  232 non-null    object
#  5   Unnamed: 5  235 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 13.3+ KB

# %%
df_Energy.describe()
# Out:
#        Unnamed: 0
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df_Energy.isnull().sum()
# Out:
# Unnamed: 0    282
# Unnamed: 1     22
# Unnamed: 2     30
# Unnamed: 3     50
# Unnamed: 4     50
# Unnamed: 5     47
# dtype: int64

# %%
# Drop unnecessary columns
df_Energy = df_Energy.drop(df_Energy.columns[[0, 1]], axis=1)

# %%
# Rename first 2 columns

df_Energy = df_Energy.rename(columns={df_Energy.columns[0]: 'Country', df_Energy.columns[1]: 'Energy Supply'})

# %%
display(df_Energy)
# Out:
#                                                Country Energy Supply  \
# 0                     Environmental Indicators: Energy           NaN
# 1                                                  NaN           NaN
# 2    Energy Supply and Renewable Electricity Produc...           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 277                                                NaN           NaN
# 278                                                NaN           NaN
# 279                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
#
#     Unnamed: 4                  Unnamed: 5
# 0          NaN                         NaN
# 1          NaN                         NaN
# ...

# %%
# Convert Energy Supply to gigajoules
df_Energy ['Energy Supply'] = df_Energy['Energy Supply'] * 1000000

# %%
# Replace missing values with NaN
df_Energy = df_Energy.replace('...', np.nan)

# %%
# Rename countries
country_map = {
    "Republic of Korea": "South Korea",
    "United States of America": "United States",
    "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
    "China, Hong Kong Special Administrative Region": "Hong Kong",
    "Bolivia": "Bolivia",
    "Switzerland17": "Switzerland"
}
df_Energy ['Country'] = df_Energy ['Country'].replace(country_map)

# %%
#Step 1 World_bank data
df_GDP = pd.read_csv('world_bank.csv')

# %%
df_GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Data Source                   266 non-null    object
#  1   World Development Indicators  266 non-null    object
#  2   Unnamed: 2                    265 non-null    object
#  3   Unnamed: 3                    265 non-null    object
#  4   Unnamed: 4                    120 non-null    float64
#  5   Unnamed: 5                    121 non-null    float64
#  6   Unnamed: 6                    121 non-null    float64
#  7   Unnamed: 7                    121 non-null    float64
#  8   Unnamed: 8                    121 non-null    float64
#  9   Unnamed: 9                    128 non-null    float64
#  10  Unnamed: 10                   133 non-null    float64
#  11  Unnamed: 11                   134 non-null    float64
# ...

# %%
df_GDP.describe()
# Out:
#          Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8  \
# count  1.200000e+02  1.210000e+02  1.210000e+02  1.210000e+02  1.210000e+02
# mean   6.257208e+11  6.459837e+11  6.807291e+11  7.159826e+11  7.639482e+11
# std    1.802999e+12  1.876752e+12  1.983556e+12  2.087261e+12  2.223217e+12
# min    1.960000e+03  1.961000e+03  1.962000e+03  1.963000e+03  1.964000e+03
# 25%    2.681403e+09  2.925140e+09  3.195914e+09  3.465094e+09  3.622063e+09
# 50%    2.770444e+10  2.893825e+10  3.057948e+10  3.244990e+10  3.401781e+10
# 75%    2.442844e+11  2.483267e+11  2.628428e+11  2.794047e+11  2.944458e+11
# max    1.118678e+13  1.166806e+13  1.231357e+13  1.295118e+13  1.381212e+13
#
#          Unnamed: 9   Unnamed: 10   Unnamed: 11   Unnamed: 12   Unnamed: 13  \
# count  1.280000e+02  1.330000e+02  1.340000e+02  1.380000e+02  1.380000e+02
# mean   7.653989e+11  7.794300e+11  8.069764e+11  8.370457e+11  8.901126e+11
# ...

# %%
df_GDP.head()
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                   2016-07-22
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                  Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                       NaN             NaN         NaN
# 1                                       NaN             NaN         NaN
# 2                                       NaN             NaN         NaN
# 3                            Indicator Name  Indicator Code      1960.0
# 4  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
# Create a dictionary to map old names to new names
country_dictionary = {
    'Korea': 'South Korea',
    'Iran, Islamic Rep.': 'Iran',
    'Hong Kong SAR, China': 'Hong Kong'
}

# %%
print (df_GDP.head())
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                   2016-07-22
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                  Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                       NaN             NaN         NaN
# 1                                       NaN             NaN         NaN
# 2                                       NaN             NaN         NaN
# 3                            Indicator Name  Indicator Code      1960.0
# 4  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
#Step 2 load Sciamgo Journal and Country Rank data
df_ScimEn = pd.read_excel('scimagojr-3.xlsx') # Use pd.read_excel for reading xlsx files

# %%
#merging datasets:
def merge_datasets(df_gdp, df_Energy, df_ScimEn):
    gdp_filtered = df_gdp[['Country Name'] + df_gdp.columns[4:15].tolist()]
    scimen_top15 = df_ScimEn.head(15)

# %%
#merging datasets:
def merge_datasets(df_gdp, df_Energy, df_ScimEn):
    gdp_filtered = df_gdp[['Country Name'] + df_gdp.columns[4:15].tolist()]
    scimen_top15 = df_ScimEn.head(15)
    df_merged = pd.merge(pd.merge(gdp_filtered, df_Energy, left_on='Country Name', right_on='Country'), scimen_top15, on='Country')
    return df_merged # remove extra indent and correct the variable name from merged to df_merged

# %%
def compute_statistics(merged_df):
    merged_df.set_index('Country', inplace=True)

# %%
def compute_statistics(merged_df):
    merged_df.set_index('Country', inplace=True)
    avg_gdp = merged_df[merged_df.columns[4:15]].mean(axis=1).sort_values(ascending=False)
    print("Average GDP over the last 10 years:\n", avg_gdp) # remove extra indent

# %%
def compute_statistics(merged_df):
    merged_df.set_index('Country', inplace=True)
    avg_gdp = merged_df[merged_df.columns[4:15]].mean(axis=1).sort_values(ascending=False)
    print("Average GDP over the last 10 years:\n", avg_gdp)
    merged_df['Energy Supply per Capita'] = merged_df['Energy Supply'] / merged_df['PopEst'] #remove extra indent
    mean_energy_per_capita = merged_df['Energy Supply per Capita'].mean()
    print("\nMean Energy Supply per Capita:", mean_energy_per_capita)

# %%
def compute_statistics(merged_df):
    merged_df.set_index('Country', inplace=True)
    avg_gdp = merged_df[merged_df.columns[4:15]].mean(axis=1).sort_values(ascending=False)
    print("Average GDP over the last 10 years:\n", avg_gdp)
    merged_df['Energy Supply per Capita'] = merged_df['Energy Supply'] / merged_df['PopEst']
    mean_energy_per_capita = merged_df['Energy Supply per Capita'].mean()
    print("\nMean Energy Supply per Capita:", mean_energy_per_capita)
    merged_df['Citation Ratio'] = merged_df['Self-citations'] / merged_df['Citations'].replace(0, np.nan)

    if 'Citation Ratio' in merged_df.columns and merged_df['Citation Ratio'].notnull().any():
        max_ratio_country = merged_df['Citation Ratio'].idxmax()
        max_ratio_value = merged_df['Citation Ratio'].max()
        print(f"Country with maximum citation ratio: {max_ratio_country} ({max_ratio_value})")
    else:
        print("No valid 'Citation Ratio' values found. Check your data and merging process.")

# %%
def main():
    energy_file_path = '/content/Energy Indicators.xlsx'
    gdp_file_path = '/content/world_bank.xlsx'
    scimen_file_path = '/content/scimagojr-3.xlsx'

    # The following lines were incorrectly indented. They should be indented to be part of the main function.
    energy_df = load_data(energy_file_path, skip_rows=16, skip_footer=38)
    gdp_df = load_data(gdp_file_path)
    scimen_df = load_data(scimen_file_path)

# %%
def main():
    energy_file_path = '/content/Energy Indicators.xlsx'
    gdp_file_path = '/content/world_bank.xlsx'
    scimen_file_path = '/content/scimagojr-3.xlsx'

    # The following lines were incorrectly indented. They should be indented to be part of the main function.
    energy_df = load_data(energy_file_path, skip_rows=16, skip_footer=38)
    gdp_df = load_data(gdp_file_path)
    scimen_df = load_data(scimen_file_path)

    energy_df = preprocess_energy(energy_df)
    gdp_df = preprocess_gdp(gdp_df)
    scimen_df = filter_scimen(scimen_df)

# %%
def main():
    energy_file_path = '/content/Energy Indicators.xlsx'
    gdp_
